# %%
import pandas as pd

# %%
df=pd.read_csv('/content/bank-additional-full organised.csv')

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
#drop unwanted columns
df=df.drop(['emp.var.rate','cons.price.idx','cons.conf.idx',
            'euribor3m','nr.employed'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          41188 non-null  int64
#  1   job          41188 non-null  object
#  2   marital      41188 non-null  object
#  3   education    41188 non-null  object
#  4   default      41188 non-null  object
#  5   housing      41188 non-null  object
#  6   loan         41188 non-null  object
#  7   contact      41188 non-null  object
#  8   month        41188 non-null  object
#  9   day_of_week  41188 non-null  object
#  10  duration     41188 non-null  int64
#  11  campaign     41188 non-null  int64
#  12  pdays        41188 non-null  int64
#  13  previous     41188 non-null  int64
#  14  poutcome     41188 non-null  object
#  15  y            41188 non-null  object
# dtypes: int64(5), object(11)
# memory usage: 5.0+ MB

# %%
#check for duplicates
df.duplicated().sum()
# Out:
# np.int64(13)

# %%
#view all duplicate rows
df[df.duplicated()]
# Out:
#        age          job   marital            education  default housing loan  \
# 1266    39  blue-collar   married             basic.6y       no      no   no
# 12261   36      retired   married              unknown       no      no   no
# 14234   27   technician    single  professional.course       no      no   no
# 16956   47   technician  divorced          high.school       no     yes   no
# 18465   32   technician    single  professional.course       no     yes   no
# 20216   55     services   married          high.school  unknown      no   no
# 20534   41   technician   married  professional.course       no     yes   no
# 25217   39       admin.   married    university.degree       no      no   no
# 28477   24     services    single          high.school       no     yes   no
# 32516   35       admin.   married    university.degree       no     yes   no
# 33296   36  blue-collar   married             basic.9y       no      no   no
# ...

# %%
#remove duplicates
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41175 entries, 0 to 41187
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          41175 non-null  int64
#  1   job          41175 non-null  object
#  2   marital      41175 non-null  object
#  3   education    41175 non-null  object
#  4   default      41175 non-null  object
#  5   housing      41175 non-null  object
#  6   loan         41175 non-null  object
#  7   contact      41175 non-null  object
#  8   month        41175 non-null  object
#  9   day_of_week  41175 non-null  object
#  10  duration     41175 non-null  int64
#  11  campaign     41175 non-null  int64
#  12  pdays        41175 non-null  int64
#  13  previous     41175 non-null  int64
#  14  poutcome     41175 non-null  object
#  15  y            41175 non-null  object
# dtypes: int64(5), object(11)
# memory usage: 5.3+ MB

# %%
#check for missing values
print(df.isnull().sum())
# Out:
# age            0
# job            0
# marital        0
# education      0
# default        0
# housing        0
# loan           0
# contact        0
# month          0
# day_of_week    0
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# y              0
# dtype: int64

# %%
#keeping only rows with age between 18 and 90
df = df[(df['age'] >= 18) & (df['age'] <= 90)]

# %%
#checking new min and max age
print(df['age'].min(), df['age'].max())
# Out:
# 18 89

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41160 entries, 0 to 41187
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          41160 non-null  int64
#  1   job          41160 non-null  object
#  2   marital      41160 non-null  object
#  3   education    41160 non-null  object
#  4   default      41160 non-null  object
#  5   housing      41160 non-null  object
#  6   loan         41160 non-null  object
#  7   contact      41160 non-null  object
#  8   month        41160 non-null  object
#  9   day_of_week  41160 non-null  object
#  10  duration     41160 non-null  int64
#  11  campaign     41160 non-null  int64
#  12  pdays        41160 non-null  int64
#  13  previous     41160 non-null  int64
#  14  poutcome     41160 non-null  object
#  15  y            41160 non-null  object
# dtypes: int64(5), object(11)
# memory usage: 5.3+ MB

# %%
#reset index and add id column
df.reset_index(drop=True, inplace=True)
df.insert(0, 'id', range(1, len(df) + 1))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41160 entries, 0 to 41159
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           41160 non-null  int64
#  1   age          41160 non-null  int64
#  2   job          41160 non-null  object
#  3   marital      41160 non-null  object
#  4   education    41160 non-null  object
#  5   default      41160 non-null  object
#  6   housing      41160 non-null  object
#  7   loan         41160 non-null  object
#  8   contact      41160 non-null  object
#  9   month        41160 non-null  object
#  10  day_of_week  41160 non-null  object
#  11  duration     41160 non-null  int64
#  12  campaign     41160 non-null  int64
#  13  pdays        41160 non-null  int64
#  14  previous     41160 non-null  int64
#  15  poutcome     41160 non-null  object
#  16  y            41160 non-null  object
# dtypes: int64(6), object(11)
# memory usage: 5.3+ MB

# %%
#save the cleaned dataset
df.to_csv("bank_data_clean.csv", index=False)

# %%
print(f"✅ Preprocessing complete! Rows: {len(df)}")
# Out:
# ✅ Preprocessing complete! Rows: 41160
